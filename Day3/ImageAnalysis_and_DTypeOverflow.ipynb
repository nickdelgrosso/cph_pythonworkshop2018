# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = plt.imread('/home/nickdg/Desktop/A-gray-cat-crying-looking-upset.jpg')
im[:, :, 0]
# Out:
# array([[245, 246, 246, ...,  21,  16,  17],
#        [248, 245, 246, ...,  21,  20,  16],
#        [246, 245, 244, ...,  18,  15,  17],
#        ...,
#        [ 78,  75,  80, ...,  40,  43,  46],
#        [ 79,  80,  78, ...,  40,  41,  41],
#        [ 75,  77,  81, ...,  40,  40,  35]], dtype=uint8)

# %%
im.flags.writeable = True
im.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
plt.imshow(im)

# %%
aa = np.array([0, None, 3], dtype=float)
np.nanmean(aa)
# Out:
# 1.5

# %%
face = im[100:250, 200:500, :]
plt.imshow(face)

# %%
x = 1
x += 1
x *= 3
x
# Out:
# 6

# %%
face += 20
plt.imshow(face)

# %%
plt.imshow(im)

# %%
from tqdm import tqdm

for el in tqdm(range(100000000)):
    a = 10
# Out:
# 100%|██████████| 100000000/100000000 [00:24<00:00, 4109368.45it/s]
